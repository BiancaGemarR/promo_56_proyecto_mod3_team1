# %%
import csv 
import json 
import pandas as pd
pd.set_option("display.max_columns", None)
#pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv('hr_raw_data.csv', index_col=0)
df
# Out:
#      age attrition businesstravel    dailyrate                department  \
# 0     51        No            NaN  2015.722222                       NaN
# 1     52        No            NaN  2063.388889                       NaN
# 2     42        No  travel_rarely  1984.253968   Research & Development
# 3     47        No  travel_rarely  1771.404762                       NaN
# 4     46        No            NaN  1582.771346                       NaN
# ...   ..       ...            ...          ...                       ...
# 1673  43        No            NaN   488.944444                       NaN
# 1674  47        No            NaN  1973.984127                       NaN
# 1675  29        No  travel_rarely   290.035510                       NaN
# 1676  47        No  travel_rarely  1032.487286                       NaN
# 1677  32        No            NaN   556.256661                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# ...

# %%
#transformar el 0 y 1 por estereotipos de género como masculino y femenino con asignación directa, la empresa debe
#replantearse el non-binary
df['gender'] = df['gender'].replace(0, 'M')

df['gender'] = df['gender'].replace(1, 'F')
print(df['gender'])
# Out:
# 0       M
# 1       M
# 2       M
# 3       F
# 4       F
#        ..
# 1673    F
# 1674    F
# 1675    M
# 1676    F
# 1677    F
# Name: gender, Length: 1678, dtype: object

# %%
df['gender'].replace(0, 'M', inplace= True)
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_16164\334614887.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace(0, 'M', inplace= True)

# %%
df['gender'].replace(1, 'F', inplace= True)
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_16164\2907064674.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace(1, 'F', inplace= True)

# %%
df
# Out:
#      age attrition businesstravel    dailyrate                department  \
# 0     51        No            NaN  2015.722222                       NaN
# 1     52        No            NaN  2063.388889                       NaN
# 2     42        No  travel_rarely  1984.253968   Research & Development
# 3     47        No  travel_rarely  1771.404762                       NaN
# 4     46        No            NaN  1582.771346                       NaN
# ...   ..       ...            ...          ...                       ...
# 1673  43        No            NaN   488.944444                       NaN
# 1674  47        No            NaN  1973.984127                       NaN
# 1675  29        No  travel_rarely   290.035510                       NaN
# 1676  47        No  travel_rarely  1032.487286                       NaN
# 1677  32        No            NaN   556.256661                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# ...

# %%
df['dailyrate']=df['dailyrate'].round(2)

# %%
df
# Out:
#      age attrition businesstravel  dailyrate                department  \
# 0     51        No            NaN    2015.72                       NaN
# 1     52        No            NaN    2063.39                       NaN
# 2     42        No  travel_rarely    1984.25   Research & Development
# 3     47        No  travel_rarely    1771.40                       NaN
# 4     46        No            NaN    1582.77                       NaN
# ...   ..       ...            ...        ...                       ...
# 1673  43        No            NaN     488.94                       NaN
# 1674  47        No            NaN    1973.98                       NaN
# 1675  29        No  travel_rarely     290.04                       NaN
# 1676  47        No  travel_rarely    1032.49                       NaN
# 1677  32        No            NaN     556.26                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# ...

# %%
df['distancefromhome'] = df['distancefromhome'].abs() #método para convertir números negativos en positivos abs

# %%
df['distancefromhome'].unique()
# Out:
# array([ 6,  1,  4,  2,  3, 22, 25,  9,  7, 23, 10, 12, 14, 13, 15,  8, 42,
#        28, 37,  5, 16, 35, 26, 24, 29, 17, 21, 18, 30, 27, 20, 31, 39, 11,
#        19, 33, 34, 46, 36, 45, 47, 32, 41, 49, 48, 38, 43, 40, 44],
#       dtype=int64)

# %%
df
# Out:
#      age attrition businesstravel  dailyrate                department  \
# 0     51        No            NaN    2015.72                       NaN
# 1     52        No            NaN    2063.39                       NaN
# 2     42        No  travel_rarely    1984.25   Research & Development
# 3     47        No  travel_rarely    1771.40                       NaN
# 4     46        No            NaN    1582.77                       NaN
# ...   ..       ...            ...        ...                       ...
# 1673  43        No            NaN     488.94                       NaN
# 1674  47        No            NaN    1973.98                       NaN
# 1675  29        No  travel_rarely     290.04                       NaN
# 1676  47        No  travel_rarely    1032.49                       NaN
# 1677  32        No            NaN     556.26                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
nuevas_columnas = {columna: columna.lower() for columna in df.columns}
nuevas_columnas
# Out:
# {'age': 'age',
#  'attrition': 'attrition',
#  'businesstravel': 'businesstravel',
#  'dailyrate': 'dailyrate',
#  'department': 'department',
#  'distancefromhome': 'distancefromhome',
#  'education': 'education',
#  'educationfield': 'educationfield',
#  'employeecount': 'employeecount',
#  'employeenumber': 'employeenumber',
#  'environmentsatisfaction': 'environmentsatisfaction',
#  'gender': 'gender',
#  'hourlyrate': 'hourlyrate',
#  'jobinvolvement': 'jobinvolvement',
#  'joblevel': 'joblevel',
#  'jobrole': 'jobrole',
#  'jobsatisfaction': 'jobsatisfaction',
#  'maritalstatus': 'maritalstatus',
#  'monthlyincome': 'monthlyincome',
#  'monthlyrate': 'monthlyrate',
#  'numcompaniesworked': 'numcompaniesworked',
#  'over18': 'over18',
#  'overtime': 'overtime',
#  'percentsalaryhike': 'percentsalaryhike',
#  'performancerating': 'performancerating',
#  'relationshipsatisfaction': 'relationshipsatisfaction',
#  'standardhours': 'standardhours',
# ...

# %%
df.rename(columns=nuevas_columnas, inplace= True)

# %%
df
# Out:
#      age attrition businesstravel  dailyrate                department  \
# 0     51        No            NaN    2015.72                       NaN
# 1     52        No            NaN    2063.39                       NaN
# 2     42        No  travel_rarely    1984.25   Research & Development
# 3     47        No  travel_rarely    1771.40                       NaN
# 4     46        No            NaN    1582.77                       NaN
# ...   ..       ...            ...        ...                       ...
# 1673  43        No            NaN     488.94                       NaN
# 1674  47        No            NaN    1973.98                       NaN
# 1675  29        No  travel_rarely     290.04                       NaN
# 1676  47        No  travel_rarely    1032.49                       NaN
# 1677  32        No            NaN     556.26                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# ...

# %%
df.drop('employeecount', axis= 1, inplace= True)

# %%
df
# Out:
#      age attrition businesstravel  dailyrate                department  \
# 0     51        No            NaN    2015.72                       NaN
# 1     52        No            NaN    2063.39                       NaN
# 2     42        No  travel_rarely    1984.25   Research & Development
# 3     47        No  travel_rarely    1771.40                       NaN
# 4     46        No            NaN    1582.77                       NaN
# ...   ..       ...            ...        ...                       ...
# 1673  43        No            NaN     488.94                       NaN
# 1674  47        No            NaN    1973.98                       NaN
# 1675  29        No  travel_rarely     290.04                       NaN
# 1676  47        No  travel_rarely    1032.49                       NaN
# 1677  32        No            NaN     556.26                       NaN
#
#       distancefromhome  education    educationfield  employeenumber  \
# ...

# %%
df['employeenumber'].duplicated() #EMPLOYEE NUMBER DUPLICADOS POR EL FINAL
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1673     True
# 1674     True
# 1675     True
# 1676     True
# 1677     True
# Name: employeenumber, Length: 1678, dtype: bool

# %%
df[df.duplicated(subset='employeenumber', keep=False)].sort_values('employeenumber') #encuestas distintas??
# Out:
#      age attrition businesstravel  dailyrate department  distancefromhome  \
# 8     41        No            NaN    1712.18        NaN                 2
# 1656  41        No            NaN    1712.18        NaN                 2
# 60    36        No            NaN     610.17        NaN                 5
# 1652  36        No            NaN     610.17        NaN                 5
# 1676  47        No  travel_rarely    1032.49        NaN                 4
# ...   ..       ...            ...        ...        ...               ...
# 1638  48        No  travel_rarely     417.96        NaN                 2
# 1657  45        No  travel_rarely     495.75        NaN                 2
# 1568  45        No  travel_rarely     495.75        NaN                 2
# 1671  31        No            NaN     556.26        NaN                12
# 1607  31        No            NaN     556.26        NaN                12
#
#       education educationfield  employeenumber  environmentsatisfaction  \
# ...

# %%
df['environmentsatisfaction'].unique()
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43], dtype=int64)

# %%
df['environmentsatisfaction'].value_counts()
# Out:
# environmentsatisfaction
# 4     483
# 3     471
# 2     316
# 1     306
# 35      7
# 12      7
# 14      6
# 13      6
# 24      5
# 47      5
# 36      4
# 48      4
# 41      4
# 46      4
# 42      4
# 45      3
# 11      3
# 22      3
# 17      3
# 18      3
# 20      3
# 25      3
# 27      3
# 37      2
# 29      2
# 19      2
# 38      2
# 31      2
# 15      2
# 16      2
# 26      1
# 39      1
# 10      1
# 49      1
# 21      1
# 28      1
# 33      1
# 43      1
# Name: count, dtype: int64

# %%
df['maritalstatus'] = df['maritalstatus'].str.capitalize()

# %%
df['maritalstatus'] = df['maritalstatus'].replace("Marreid", "Married")

# %%
df['maritalstatus'].isna().sum() #estos son no sabe no contesta, pregunta no obligatoria
# Out:
# 675

# %%
df #Monthlyrate, Monthlyincome, salary, Hourlyrate, Dailyrate, percentsalaryhike
df[['monthlyincome', 'salary', 'monthlyrate', 'dailyrate', 'hourlyrate']]
# Out:
#      monthlyincome      salary monthlyrate  dailyrate  hourlyrate
# 0        16280,83$  195370,00$   42330,17$    2015.72         NaN
# 1              NaN  199990,00$   43331,17$    2063.39         NaN
# 2              NaN  192320,00$   41669,33$    1984.25         NaN
# 3        14307,50$  171690,00$   37199,50$    1771.40         NaN
# 4        12783,92$         NaN   33238,20$    1582.77         NaN
# ...            ...         ...         ...        ...         ...
# 1673      3949,17$         NaN   10267,83$     488.94         NaN
# 1674     15943,72$  191324,62$   41453,67$    1973.98         NaN
# 1675           NaN   28111,13$    6090,75$     290.04         NaN
# 1676      8339,32$  100071,84$   21682,23$    1032.49         NaN
# 1677           NaN   53914,11$   11681,39$     556.26   69.532083
#
# [1678 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# totalworkingyears            549
# ...

# %%
df[df['monthlyrate'].isna()].isna().sum() #el oro de los incas, tiene todas las columnas
# Out:
# age                         0
# attrition                   0
# businesstravel              0
# dailyrate                   0
# department                  0
# distancefromhome            0
# education                   0
# educationfield              0
# employeenumber              0
# environmentsatisfaction     0
# gender                      0
# hourlyrate                  0
# jobinvolvement              0
# joblevel                    0
# jobrole                     0
# jobsatisfaction             0
# maritalstatus               0
# monthlyincome               0
# monthlyrate                 0
# numcompaniesworked          0
# over18                      0
# overtime                    0
# percentsalaryhike           0
# performancerating           0
# relationshipsatisfaction    0
# standardhours               0
# stockoptionlevel            0
# totalworkingyears           0
# trainingtimeslastyear       0
# worklifebalance             0
# yearsatcompany              0
# ...

# %%
df['monthlyincome'].isnull().sum()
# Out:
# 489

# %%
df['salary'].isnull().sum()
# Out:
# 285

# %%
df[df['salary'].isna()].isna().sum() #no hay coincidencias de nulos en las mismas filas de las col 'Salary y Monthlyincome'
# Out:
# age                           0
# attrition                     0
# businesstravel              144
# dailyrate                     0
# department                  235
# distancefromhome              0
# education                     0
# educationfield              140
# employeenumber                0
# environmentsatisfaction       0
# gender                        0
# hourlyrate                  285
# jobinvolvement                0
# joblevel                      0
# jobrole                       0
# jobsatisfaction               0
# maritalstatus               119
# monthlyincome                 0
# monthlyrate                   0
# numcompaniesworked            0
# over18                      167
# overtime                    120
# percentsalaryhike             0
# performancerating            38
# relationshipsatisfaction      0
# standardhours               285
# stockoptionlevel              0
# totalworkingyears            99
# trainingtimeslastyear         0
# ...

# %%
df['performancerating'].unique() #va del 1 al 4, mantener los nulos, intentar profundizar con el job role o job department
# Out:
# array(['3,0', '4,0', nan], dtype=object)

# %%
df['performancerating'].isna().sum()/df.shape[0]*100
# Out:
# 11.918951132300357

# %%
df['standardhours'].unique() #full time son 40h, part time son 20h semanales
# Out:
# array(['Full Time', nan, 'Part Time'], dtype=object)

# %%
df['standardhours'].value_counts() #Nan de esta columna son full time, hay que corregir
# Out:
# standardhours
# Part Time    927
# Full Time    400
# Name: count, dtype: int64

# %%
df['stockoptionlevel'].unique() #te dan paquetes de acciones
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df['numberchildren'].isnull().sum()/df.shape[0]*100
# Out:
# 100.0

# %%
df['numberchildren'].unique() #recomendación para la conciliación/worklifebalance
# Out:
# array([nan])

# %%
df[['monthlyincome', 'salary', 'monthlyrate', 'dailyrate', 'hourlyrate']]
# Out:
#      monthlyincome      salary monthlyrate  dailyrate  hourlyrate
# 0        16280,83$  195370,00$   42330,17$    2015.72         NaN
# 1              NaN  199990,00$   43331,17$    2063.39         NaN
# 2              NaN  192320,00$   41669,33$    1984.25         NaN
# 3        14307,50$  171690,00$   37199,50$    1771.40         NaN
# 4        12783,92$         NaN   33238,20$    1582.77         NaN
# ...            ...         ...         ...        ...         ...
# 1673      3949,17$         NaN   10267,83$     488.94         NaN
# 1674     15943,72$  191324,62$   41453,67$    1973.98         NaN
# 1675           NaN   28111,13$    6090,75$     290.04         NaN
# 1676      8339,32$  100071,84$   21682,23$    1032.49         NaN
# 1677           NaN   53914,11$   11681,39$     556.26   69.532083
#
# [1678 rows x 5 columns]

# %%
df[['monthlyincome','sameasmonthlyincome']].sample(10)
# Out:
#      monthlyincome sameasmonthlyincome
# 348       9252,50$            9252,50$
# 1155      2216,67$            2216,67$
# 744       4492,84$            4492,84$
# 1087      4492,84$            4492,84$
# 1661      2342,59$            2342,59$
# 991       2342,59$            2342,59$
# 624            NaN                 NaN
# 478       4492,84$            4492,84$
# 1200           NaN                 NaN
# 1533      2342,59$            2342,59$

# %%
df=df.drop(columns=['sameasmonthlyincome'])

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'hourlyrate', 'jobinvolvement',
#        'joblevel', 'jobrole', 'jobsatisfaction', 'maritalstatus',
#        'monthlyincome', 'monthlyrate', 'numcompaniesworked', 'over18',
#        'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'datebirth', 'salary', 'roledepartament',
#        'numberchildren', 'remotework'],
#       dtype='object')

# %%
df["remotework"].unique()
# Out:
# array(['Yes', '1', 'False', '0', 'True'], dtype=object)

# %%
df['remotework'].replace("1", 'Yes', inplace= True)
df['remotework'].replace("0", 'No', inplace= True)
df['remotework'].replace("False", 'No', inplace= True)
df['remotework'].replace("True", 'Yes', inplace= True)
# Out:
# C:\Users\paula\AppData\Local\Temp\ipykernel_16164\210456681.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['remotework'].replace("1", 'Yes', inplace= True)
# C:\Users\paula\AppData\Local\Temp\ipykernel_16164\210456681.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df["remotework"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["environmentsatisfaction"].unique()
#tenemos que quedarnos solo con el primer número. hay que quitar el segundo
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43], dtype=int64)

# %%
#df["environmentsatisfaction"] = df["environmentsatisfaction"].astype(str).str[0].astype(int)

# %%
#PENDIENTE DE HACER FUNCION
# 
# def unnumero(num):

# %%
df['hourlyrate'] = df['hourlyrate'].apply(lambda x: f"{x:.2f}")
#La primera f es de formateo y la segunda f es de float y que tenga 2 dígitos después del punto.

# %%
df['hourlyrate'].unique()
# Out:
# array(['nan', '69.53', '172.84', '216.05', '79.97', '129.06', '246.75',
#        '207.17', '60.89', '36.25', '140.00', '86.24', '197.85', '61.07',
#        '245.62', '123.98', '148.44', '255.96', '134.41', '71.93',
#        '113.79', '175.10', '247.49', '220.83', '91.35', '37.77', '198.96',
#        '124.05', '247.58', '108.49', '43.18', '68.47', '32.49', '55.26',
#        '83.47', '79.26', '72.29', '45.96', '31.66', '65.19', '52.25',
#        '143.92', '113.40', '143.19', '139.87', '70.57', '97.05', '45.02',
#        '223.48', '134.98', '74.40', '67.14', '58.06', '35.05', '73.19',
#        '164.33', '43.54', '54.80', '252.60', '83.82', '46.71', '33.00',
#        '70.78', '69.23', '54.55', '81.53', '217.76', '50.76', '88.24',
#        '57.37', '115.27', '35.78', '59.96', '28.21', '54.91', '227.49',
#        '78.18', '54.09', '177.02', '52.97', '46.39', '80.89', '118.70',
#        '56.40', '31.34', '38.36', '35.67', '84.00', '55.25', '28.71',
# ...

# %%
df['hourlyrate'].isnull()  #el monthly rate sí tiene la info.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1673    False
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# Name: hourlyrate, Length: 1678, dtype: bool

# %%
df['monthlyrate']=df['monthlyrate'].astype(str)
#cambiar de fvuelta a string para testear cosas. celda para borrar si eso np.

# %%
df['monthlyrate'] = df['monthlyrate'].str.replace('$', '', regex=False)
df['monthlyrate'] = df['monthlyrate'].str.replace(',', '.', regex=False)
df['monthlyrate'] = df['monthlyrate'].astype(float)

# %%
df['age'].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 'forty-seven', '53',
#        '43', '60', '32', '37', '49', '39', '50', '44', '30',
#        'fifty-eight', '29', '31', '54', '57', '27', 'thirty-six', '28',
#        '26', 'fifty-five', '25', 'fifty-two', 'thirty-one', '24',
#        'thirty', '23', '22', '21', '20', 'twenty-six', '19',
#        'thirty-seven', '18', 'thirty-two', 'twenty-four'], dtype=object)

# %%
df['datebirth'].unique()
# Out:
# array([1972, 1971, 1981, 1976, 1977, 1975, 1964, 1982, 1967, 1985, 1968,
#        1983, 1965, 1988, 1978, 1990, 1987, 1989, 1970, 1980, 1963, 1991,
#        1986, 1974, 1984, 1973, 1979, 1993, 1994, 1992, 1969, 1966, 1996,
#        1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005],
#       dtype=int64)

# %%
df.head(2)
# Out:
#   age attrition businesstravel  dailyrate department  distancefromhome  \
# 0  51        No            NaN    2015.72        NaN                 6
# 1  52        No            NaN    2063.39        NaN                 1
#
#    education educationfield  employeenumber  environmentsatisfaction gender  \
# 0          3            NaN               1                        1      M
# 1          4  Life Sciences               2                        3      M
#
#   hourlyrate  jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0        nan               3         5   resEArch DIREcToR                 3
# 1        nan               2         5             ManAGeR                 3
#
#   maritalstatus monthlyincome  monthlyrate  numcompaniesworked over18  \
# 0           NaN     16280,83$     42330.17                   7      Y
# 1           NaN           NaN     43331.17                   0    NaN
#
# ...

# %%
df['fin'] = 2023

# %%
df['age']= 2023 - df['datebirth']
df['age']
# Out:
# 0       51
# 1       52
# 2       42
# 3       47
# 4       46
#         ..
# 1673    43
# 1674    47
# 1675    29
# 1676    47
# 1677    32
# Name: age, Length: 1678, dtype: int64

# %%
df['businesstravel'].isnull().sum() #NOSABENORESPONDE?
# Out:
# 801

# %%
df['dailyrate'].isnull().sum()
# Out:
# 0

# %%
df.drop(['hourlyrate'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'jobinvolvement', 'joblevel',
#        'jobrole', 'jobsatisfaction', 'maritalstatus', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'over18', 'overtime',
#        'percentsalaryhike', 'performancerating', 'relationshipsatisfaction',
#        'standardhours', 'stockoptionlevel', 'totalworkingyears',
#        'trainingtimeslastyear', 'worklifebalance', 'yearsatcompany',
#        'yearsincurrentrole', 'yearssincelastpromotion', 'yearswithcurrmanager',
#        'datebirth', 'salary', 'roledepartament', 'numberchildren',
#        'remotework', 'fin'],
#       dtype='object')

# %%
df['joblevel'].unique()
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
df['jobrole']= df['jobrole'].str.lower()

# %%
df.head(2)
# Out:
#    age attrition businesstravel  dailyrate department  distancefromhome  \
# 0   51        No            NaN    2015.72        NaN                 6
# 1   52        No            NaN    2063.39        NaN                 1
#
#    education educationfield  employeenumber  environmentsatisfaction gender  \
# 0          3            NaN               1                        1      M
# 1          4  Life Sciences               2                        3      M
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   research director                 3
# 1               2         5             manager                 3
#
#   maritalstatus monthlyincome  monthlyrate  numcompaniesworked over18  \
# 0           NaN     16280,83$     42330.17                   7      Y
# 1           NaN           NaN     43331.17                   0    NaN
#
#   overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# ...

# %%
df['monthlyincome']
# Out:
# 0       16280,83$
# 1             NaN
# 2             NaN
# 3       14307,50$
# 4       12783,92$
#           ...
# 1673     3949,17$
# 1674    15943,72$
# 1675          NaN
# 1676     8339,32$
# 1677          NaN
# Name: monthlyincome, Length: 1678, dtype: object

# %%
# Replace NaN in 'salary' with monthlyincome * 12
df['salary'] = df['salary'].fillna(df['monthlyincome'] * 12)

# %%
df['salary'].isna().sum()
# Out:
# 0

# %%
df['over18']
# Out:
# array(['Y', nan], dtype=object)

# %%
df.drop(['over18'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'jobinvolvement', 'joblevel',
#        'jobrole', 'jobsatisfaction', 'maritalstatus', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'overtime', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'standardhours',
#        'stockoptionlevel', 'totalworkingyears', 'trainingtimeslastyear',
#        'worklifebalance', 'yearsatcompany', 'yearsincurrentrole',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'datebirth',
#        'salary', 'roledepartament', 'numberchildren', 'remotework', 'fin'],
#       dtype='object')

# %%
df.to_csv("hr_raw_data_2023.csv", index=False)

# %%
df1= pd.read_csv("hr_raw_data_2023.csv")

# %%
df1.drop(['fin'], axis=1, inplace=True)

# %%
df1.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeenumber',
#        'environmentsatisfaction', 'gender', 'jobinvolvement', 'joblevel',
#        'jobrole', 'jobsatisfaction', 'maritalstatus', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'overtime', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'standardhours',
#        'stockoptionlevel', 'totalworkingyears', 'trainingtimeslastyear',
#        'worklifebalance', 'yearsatcompany', 'yearsincurrentrole',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'datebirth',
#        'salary', 'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df1['yearsincurrentrole'].unique() #trabajos temporales?? los nulos están bien, no se analiza
# Out:
# array([nan, '13,0', '12,0', '11,0', '7,0', '6,0', '4,0', '3,0', '2,0',
#        '1,0', '0,0'], dtype=object)

# %%
df1['yearsincurrentrole'].isnull().sum()
# Out:
# 1643

# %%
df['yearssincelastpromotion'].isnull().sum()
# Out:
# 0
